# %%
import pandas as pd
from dash import Dash, html, dcc, Input, Output, dash_table
import plotly.express as px
import numpy as np

# %%
Dashdf = pd.read_csv("fahrdaten.csv")

#Optional timestampspalte in Zeitwerte konvertieren
Dashdf["timestamp"] = pd.to_datetime(Dashdf["timestamp"], unit="s")
Dashdf["fahrzeit_s"] = (Dashdf["timestamp"] - Dashdf["timestamp"].iloc[0]).dt.total_seconds()
Dashdf
# Out:
#                  timestamp  speed  steering_angle  direction  distance  \
# 0  2024-11-13 03:05:22.000    2.0              90          1       120
# 1  2024-11-13 03:05:22.500    2.2              92          1       118
# 2  2024-11-13 03:05:23.000    2.5              95          1       115
# 3  2024-11-13 03:05:23.500    2.7             100          1       110
# 4  2024-11-13 03:05:24.000    2.5             105          1       105
# 5  2024-11-13 03:05:24.500    2.3             108          1       100
# 6  2024-11-13 03:05:25.000    2.0             110          1        95
# 7  2024-11-13 03:05:25.500    1.8             112          1        90
# 8  2024-11-13 03:05:26.000    1.5             115          1        85
# 9  2024-11-13 03:05:26.500    1.2             118          1        80
# 10 2024-11-13 03:05:27.000    1.0             120          1        75
# 11 2024-11-13 03:05:27.500    0.8             122          1        70
# ...

# %%
max_speed=Dashdf["speed"].max()
min_speed=Dashdf["speed"].min()
avg_speed=Dashdf["speed"].mean()
total_dist=(Dashdf["speed"] * Dashdf["fahrzeit_s"]).sum()
s = Dashdf["timestamp"].dropna().sort_values()                      # Werte sortieren
total_time=s.iloc[-1] - s.iloc[0]
total_time
# Out:
# Timedelta('0 days 00:00:19.500000')

# %%
from jupyter_dash import JupyterDash                    #nur notwendig für jupyter Notebook!!

app = JupyterDash(__name__)


#app = Dash(__name__)  # <— gleicher Name wie unten verwenden!

app.layout = html.Div([
    html.H3('My First App with Data'),
    dash_table.DataTable(
        data=Dashdf.to_dict('records'),
        columns=[{"name": c, "id": c} for c in Dashdf.columns],
        page_size=10
    )
])

if __name__ == "__main__":
    app.run_server(host="0.0.0.0", port=8053, debug=False, use_reloader=False)             
    #app.run_server(mode="external", port=8052)                                          #nur notwendig für jypiter Notebook
# Out:
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8053
#  * Running on http://192.168.178.78:8053
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Nov/2025 10:25:40] "GET /_alive_f269fe34-7a6b-4d64-9f13-78d173837123 HTTP/1.1" 200 -
# Dash app running on http://0.0.0.0:8053/

# %%
#Nur für Jupyter Dash notwendig
try:
    app.stop()   # JupyterDash-Methode
except Exception:
    pass
# Out:
# 192.168.178.77 - - [13/Nov/2025 10:25:49] "GET / HTTP/1.1" 200 -
# 192.168.178.77 - - [13/Nov/2025 10:25:49] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.178.77 - - [13/Nov/2025 10:25:49] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.178.77 - - [13/Nov/2025 10:25:49] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 304 -
# 192.168.178.77 - - [13/Nov/2025 10:25:49] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 304 -
